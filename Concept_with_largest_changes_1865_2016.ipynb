# %%
import comman_function as cf

# %%
# get all the vector concepts from 1st time period : 1865-1980
_1865_1980 = KeyedVectors.load('Embedding/10/1865_1980_10.vec',  mmap='r') # read file
# get all the vector concepts from 4th time period : 2004_2006
_2004_2006 = KeyedVectors.load("Embedding/10/2012_2016_10.vec",  mmap='r') # read file

# %%
changes = cf.largest_changes(concept_similarity_dict = cosine_distance_time_periods(_1865_1980,_2004_2006) )

# %%
changes
# Out:
# OrderedDict([('C2911633', 0.11137222),
#              ('C0410551', 0.12058349),
#              ('C0270273', 0.12160042),
#              ('C0153646', 0.12533495),
#              ('C0160745', 0.1305068),
#              ('srs', 0.13100803),
#              ('C0160681', 0.1313245),
#              ('C0154298', 0.13881996),
#              ('C0281778', 0.13929968),
#              ('C0340644', 0.13963015),
#              ('C2349669', 0.14101022),
#              ('C0375553', 0.14631073),
#              ('C0022927', 0.1475506),
#              ('pca', 0.1486108),
#              ('C0153474', 0.14961927),
#              ('C0270090', 0.15288958),
#              ('C0566951', 0.15666793),
#              ('C0158140', 0.15687372),
#              ('C0473472', 0.15985933),
#              ('C0477432', 0.16593842),
#              ('C3537055', 0.16948341),
#              ('C2242814', 0.17094557),
#              ('C0265374', 0.17827035),
#              ('psp', 0.1787589),
# ...

# %%
for concept,score in changes.items():
    print(concept,score)
    break
# Out:
# C0869528 0.12801884

# %%
with open('similarity_measure_1865_2016.csv','w') as fout:

    for concept,score in changes.items():
        #print(concept)
        list_of_concept =_1865_1980.most_similar(concept)
        concept_name = ''
        if concept in concept_dict:
            concept_name = concept_dict[concept]
            #print(concept_name)
        fout.write(concept+':'+str(score)+'|'+str(concept_name))

        for simi_concept in list_of_concept[:6]:
            simi_concept_name = ''
            if simi_concept[0] in concept_dict:
                simi_concept_name = concept_dict[simi_concept[0]]

            fout.write('|'+str(simi_concept) + '|' +str(simi_concept_name))
        fout.write('\n')

        list_of_concept_2 = _2004_2006.most_similar(concept)

        fout.write(concept+':'+str(score)+'|'+str(concept_name))
        for simi_concept_2 in list_of_concept_2[:6]:
            simi_concept_name_2 = ''
            if simi_concept_2[0] in concept_dict:
                simi_concept_name_2 = concept_dict[simi_concept_2[0]]

            fout.write('|' + str(simi_concept_2) + '|' + str(simi_concept_name_2))
        fout.write('\n')
# Out:
# /home/gvashisth/miniconda2/envs/myenv/lib/python3.5/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
changes['aids']
# Out:
# 0.38944057

# %%
len(changes)
# Out:
# 10182

# %%
_1865_1980.most_similar('C0869528')
# Out:
# /home/gvashisth/miniconda2/envs/myenv/lib/python3.5/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('C0375841', 0.7503555417060852),
#  ('C0158026', 0.6604946851730347),
#  ('C0153216', 0.6448684930801392),
#  ('C0553730', 0.6024476289749146),
#  ('C2745963', 0.5933330655097961),
#  ('C0152087', 0.5779833793640137),
#  ('C0851258', 0.5764415860176086),
#  ('C0157987', 0.5611519813537598),
#  ('C0008475', 0.5499554872512817),
#  ('C0041188', 0.54613196849823)]

# %%
import pandas as pd

# %%
df = pd.read_csv('similarity_measure_1865_2016.csv',delimiter='|',header=None)

# %%
df.head(2)
# Out:
#                     0                             1   \
# 0  C2911633:0.11137222  ['Candidal osteomyelitis\n']
# 1  C2911633:0.11137222  ['Candidal osteomyelitis\n']
#
#                                   2                          3   \
# 0  ('C0267762', 0.46926331520080566)  ['subhepatic; abscess\n']
# 1     ('ssoaic', 0.9485375881195068)                        NaN
#
#                                  4               5   \
# 0  ('C0085082', 0.4399559199810028)  ['fungemia\n']
# 1   ('curopsy', 0.9484775066375732)             NaN
#
#                                   6   \
# 0  ('C0021833', 0.43573129177093506)
# 1   ('C0155388', 0.9456727504730225)
#
#                                            7   \
# 0                     ['intestine fistula\n']
# 1  ['disorder of external ear (diagnosis)\n']
#
#                                   8   \
# 0  ('C0267181', 0.41668587923049927)
# 1   ('C3816504', 0.9455345273017883)
#
#                                               9   \
# ...

# %%
df.columns = ["ConceptID:_similarility","conceptname","1st_ConceptID","1st_ConceptName","2_ConceptID","2_ConceptName"\
             ,"3_ConceptID","3_ConceptName","4_ConceptID","4_ConceptName","5_ConceptID","5_ConceptName"\
             ,"6_ConceptID","6_ConceptName"]

# %%
df.head()
# Out:
#   ConceptID:_similarility                                conceptname  \
# 0     C2911633:0.11137222               ['Candidal osteomyelitis\n']
# 1     C2911633:0.11137222               ['Candidal osteomyelitis\n']
# 2     C0410551:0.12058349  ['ruptured popliteal cyst (diagnosis)\n']
# 3     C0410551:0.12058349  ['ruptured popliteal cyst (diagnosis)\n']
# 4     C0270273:0.12160042    ['neonatal slow feeding (diagnosis)\n']
#
#                        1st_ConceptID  \
# 0  ('C0267762', 0.46926331520080566)
# 1     ('ssoaic', 0.9485375881195068)
# 2   ('C0265671', 0.7739452123641968)
# 3   ('C0677499', 0.9414757490158081)
# 4   ('C3665339', 0.8312602043151855)
#
#                             1st_ConceptName  \
# 0                 ['subhepatic; abscess\n']
# 1                                       NaN
# 2        ['semilunar cartilage; discoid\n']
# 3  ['radial tunnel syndrome (diagnosis)\n']
# 4                    ['Sepsis, Neonatal\n']
#
#                           2_ConceptID  \
# ...

# %%
df.to_csv("similarity_measure_1865_2016.csv",header=True,index=False,sep=",")

# %%
# %pwd
# Out:
# '/home/gvashisth/thesis'
